# %% [markdown]
# # Домашнее задание 1
#
# Перед выполнением заданий необходимо сохранить копию этого блокнота себе на диск. Или скачать `.ipynb`/`.py` файл для локальной разработки.
#
# За работу можно получить максимум 8 баллов.

# %% [markdown]
# ## Основные задачи (8 баллов)
#
# Выполнение этих заданий поможет закрепить теорию на практике.

# %% [markdown]
# ### Ввод и вывод. Арифметические операции (2 балла)

# %% [markdown]
# Задание 1.1
#
# Напишите программу, которая считывает 3 числа a, b, c. Выведите сумму этих чисел.

# %%
a = int(input())
b = int(input())
c = int(input())
print(a+b+c)
# Out:
# 5
# 7
# 4
# 16

# %% [markdown]
# Задание 1.2
#
# Напишите программу, которая считывает 3 числа a, b, c. Выдедите среднее арифметическое этих чисел.

# %%
a = int(input())
b = int(input())
c = int(input())
print((a+b+c)/3)
# Out:
# 5
# 7
# 8
# 6.666666666666667

# %% [markdown]
# Задание 1.3
#
# Напишите программу, которая считывает число (сторону квадрата). Выведите два числа: его периметр и площадь.

# %%
a = int(input())

print(a*4, a*a)
# Out:
# 7
# 28 49

# %% [markdown]
# Задание 1.4
#
# Напишите программу, которая считывает число (время в секундах) выводит его в формате: часы, минуты и секунды.
#
# Для вычислений рекомендуем использовать операцию целочисленного деления `//` и взятия остатка от деления `%`

# %%
a = int(input())

h = a//3600
m = (a % 3600) // 60
s = a % 60

print(h, m, s)
# Out:
# 567
# 0 9 27

# %% [markdown]
# Задание 1.5
#
# Напишите программу, которая считывает имя пользователя и после приветствует его фразой `"Hello, <имя пользователя>"`.

# %%
a = str(input())
print("Hello, ", a)
# Out:
# ui
# Hello,  ui

# %% [markdown]
# Задbние 1.6
#
# Напишите программу, которая считывает три числа a, b, c и выводит значение выражения $\dfrac{a}{a^2 + 1} + \dfrac{b}{b^2 + 1} + \dfrac{c}{c^2 + 1}$

# %%
def counter(a):
    return a/(a**2+1)


a = int(input())
b = int(input())
c = int(input())

print(counter(a), counter(b), counter(c))
# Out:
# 4
# 8
# 5
# 0.23529411764705882 0.12307692307692308 0.19230769230769232

# %% [markdown]
# ### Работа со строками (2 балла)

# %% [markdown]
# Задание 2.1
#
# Напишите программу, которая считывает строку и выводит следующую информацию (каждый пункт в новой строке):
#
# 1. Третий символ этой строки
# 2. Предпоследний символ этой строки
# 3. Первые пять символов этой строки
# 4. Всю строку, кроме последних трех символов
# 5. Все символы, расположенные на четных позизиях
# 6. Все символы в обратном порядке
# 7. Длину всей строки
# 8. Количество всех символов, расположенных на нечетных позициях

# %%
a = input()
print(a[2])
print(a[-2])
print(a[:5])
print(a[:-3])
print(a[::2])
print(a[::-1])
print(len(a))
print(len(a[1::2]))
# Out:
# flg
# g
# l
# flg
#
# fg
# glf
# 3
# 1

# %% [markdown]
# ### Разные задачи (2 балла)

# %% [markdown]
# Задание 3.1
#
# Напишите программу, которая меняет значения в переменных a, b c по следующему правилу:
# * в переменную a поместить значение $a + 2b - 3c$
# * в переменную b поместить значение $a^2 + b^2 - c^2$
# * в переменную c поместить значение $\dfrac{a+b+c}{a^2+b^2+c^2+1}$
#
# Вывести значение переменных  a, b, c

# %%
a_old = float(input())
b_old = float(input())
c_old = float(input())
a = a_old + 2*b_old - 3*c_old
b = a_old**2 + b_old**2 - c_old**2
c = (a_old + b_old + c_old) / (a_old**2 + b_old**2 + c_old**2 + 1)
print(f"a = {a}")
print(f"b = {b}")
print(f"c = {c}")
# Out:
# 6
# 4
# 8
# a = -10.0
# b = -12.0
# c = 0.15384615384615385

# %% [markdown]
# Задание 3.2
#
# Напишите программу, которая выведет сумму значений кодов символов вашего имени. Рекомендуем использовать функцию `ord()`.

# %%
name = input()
sum_codes = 0
for char in name:
    sum_codes += ord(char)
print(sum_codes)
# Out:
# 6
# 54

# %% [markdown]
# ## Дополнительные задачи (8 баллов)
#
# Для ребят, кто желает попробовать свои силы в более сложных задачах.

# %% [markdown]
# Задача *.1 (2 балл)
#
# Помогите Паше написать программу, которая будет искать по трем сторона площадь треугольника. Считайте, что на вход подаются числа, которые являются сторонами существующего треугольника. Для решения рекомендуется использовать формулу Герона
# $$
# S = \sqrt{p(p-a)(p-b)(p-c)}, \quad p = \dfrac{a+b+c}{2}
# $$

# %%
import math
a = float(input())
b = float(input())
c = float(input())
p = (a + b + c) / 2
S = math.sqrt(p * (p - a) * (p - b) * (p - c))
print(S)
# Out:
# 7
# 5
# 9
# 17.41228014936585

# %% [markdown]
# Задача *.2 (2 балла)
#
# Паша очень любит кататься на общественном транспорте, а получая билет, сразу проверяет, счастливый ли ему попался. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера билета.
#
# Однако Паша очень плохо считает в уме, поэтому попросил вас написать программу, которая проверит равенство сумм и выведет "Счастливый", если суммы совпадают, и "Обычный", если суммы различны.
#
# На вход программе подаётся строка из шести цифр.
#
# Выводить нужно только слово "Счастливый" или "Обычный", с большой буквы.

# %%
ticket = input()

sum_first = int(ticket[0]) + int(ticket[1]) + int(ticket[2])
sum_second = int(ticket[3]) + int(ticket[4]) + int(ticket[5])

if sum_first == sum_second:
    print("Счастливый")
else:
    print("Обычный")
# Out:
# 678905
# Обычный

# %% [markdown]
# Задача *.3 (2 балла)
#
# [GC-состав](https://ru.wikipedia.org/wiki/GC-%D1%81%D0%BE%D1%81%D1%82%D0%B0%D0%B2) является важной характеристикой геномных последовательностей и определяется как процентное соотношение суммы всех гуанинов и цитозинов к общему числу нуклеиновых оснований в геномной последовательности.
#
# Напишите программу, которая вычисляет процентное содержание символов G (гуанин) и C (цитозин) в введенной строке (программа **не должна зависеть** от регистра вводимых символов).
#
# Например, в строке "acggtgttat" процентное содержание символов G и C равно $\dfrac{4}{10}\cdot 100 = 40.0$, где 4 - это количество символов G и C,  а 10 - это длина строки.

# %%
dna = input()
dna_upper = dna.upper()
gc_count = dna_upper.count('G') + dna_upper.count('C')
total_length = len(dna)
gc_percentage = (gc_count / total_length) * 100
print(gc_percentage)
# Out:
# 5
# 0.0

# %% [markdown]
# Задача *.4 (2 балла)
#
# Напишите программу, которая выводит наибольний и наименьший элементсписка (можно для упрощения создать список внутри программы, без считывания). Решение не должно использовать встроенную функцию `max()` или `min()`.

# %%
numbers = [12, 45, 2, 41, 31, 10, 8, 6, 4]
me = numbers[0]
maxe = numbers[0]
for num in numbers:
    if num < me:
        me = num
    if num > maxe:
        maxe = num
print(me)
print(maxe)
# Out:
# 2
# 45
